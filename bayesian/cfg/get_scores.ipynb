# %%
from molguidance.utils.sdf_utils import check_valency_charge_balance, get_uniqueness_rate, get_rdkit_valid, get_pb_valid_results

# %%
_, mol_stability, _, _ = check_valency_charge_balance("cfg_guidance_best_w.sdf")
print("stability:", mol_stability)
# Out:
# stability: 0.9633

# %%
_, uniqueness_rate = get_uniqueness_rate("cfg_guidance_best_w.sdf", n_raw=10000)
print("uniqueness:", uniqueness_rate)
# Out:
# uniqueness: 0.9493

# %%
rdkit_valid = get_rdkit_valid("cfg_guidance_best_w.sdf", n_mols=10000)
print("rdkit_valid:", rdkit_valid)
# Out:
# rdkit_valid: 0.9883
