# %%
import pickle

# %%
path = "pkl-files/double_w_cfg_results_mu.pkl"
pcikle_file = open(path, 'rb')
data = pickle.load(pcikle_file)

# %%
data
# Out:
# {'best_w1': 3.1318106881454613,
#  'best_w2': 1.8832612754246831,
#  'best_mae': 0.52148962398828,
#  'guide_ws': array([[3.38962896, 1.55030437],
#         [3.339073  , 2.79055047],
#         [2.33749826, 1.29992475],
#         [2.37774668, 2.00112583],
#         [1.42860045, 2.95266542],
#         [1.16923474, 3.16599632],
#         [3.81565813, 1.0023363 ],
#         [3.97663468, 2.85244453],
#         [2.83495948, 1.02119892],
#         [1.06918728, 2.57432398],
#         [4.        , 1.79731562],
#         [4.        , 1.49431036],
#         [3.18920003, 1.82084702],
#         [4.        , 2.08787404],
#         [4.        , 4.        ],
#         [4.        , 1.89483114],
#         [4.        , 1.87968956],
#         [4.        , 1.68988176],
#         [1.        , 1.78417636],
#         [4.        , 1.62969404],
#         [4.        , 2.39291605],
#         [2.55386402, 2.28893011],
#         [4.        , 1.51006895],
#         [2.44678918, 1.63780131],
# ...
