# %%
from molguidance.utils.sdf_utils import get_bond_entropy, get_element_entropy, get_scaffold_diversity

# %%
vanilla_sdf = "./vanilla/vanilla.sdf"
cfg_sdf = "./cfg/cfg_guidance_best_w.sdf"
ag_sdf = "./ag/ag_guidance_best_w.sdf"
mg_sdf = "./mg/mg_guidance_best_w.sdf"

sdf_files = [
        vanilla_sdf,
        cfg_sdf,
        ag_sdf,
        mg_sdf
    ]
    
method_titles = [
        'vanilla',
        'CFG',
        'AG',
        'MG'
    ]

# %%
# Get bond entropy
get_bond_entropy(sdf_files, method_titles)
# Out:
#     Method Bond Entropy                             Bond Type Distribution
# 0  vanilla        0.483  SINGLE: 152205, DOUBLE: 6993, TRIPLE: 2500, AR...
# 1      CFG        0.482  SINGLE: 153251, DOUBLE: 6530, TRIPLE: 1922, AR...
# 2       AG        0.528  SINGLE: 151291, DOUBLE: 6784, TRIPLE: 2806, AR...
# 3       MG        0.523  SINGLE: 151449, DOUBLE: 6822, TRIPLE: 1423, AR...

# %%
# get element entropy
get_element_entropy(sdf_files, method_titles)
# Out:
#     Method Shannon Entropy
# 0  vanilla           1.694
# 1      CFG           1.762
# 2       AG           1.728
# 3       MG           1.713

# %%
# get scaffold diversity
get_scaffold_diversity(sdf_files, method_titles)
# Out:
#     Method Scaffold Diversity
# 0  vanilla              0.251
# 1      CFG              0.305
# 2       AG              0.231
# 3       MG              0.281
