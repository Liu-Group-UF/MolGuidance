# %%
import pickle

# %%
path = "pkl-files/mg_results_mu.pkl"
pcikle_file = open(path, 'rb')
data = pickle.load(pcikle_file)

# %%
data
# Out:
# {'best_w': 2.2544555887099866,
#  'best_mae': 0.6097031032203231,
#  'guide_ws': array([[2.38962896e+00],
#         [5.50304370e-01],
#         [2.33907300e+00],
#         [1.79055047e+00],
#         [1.33749826e+00],
#         [2.99924747e-01],
#         [1.37774668e+00],
#         [1.00112583e+00],
#         [4.28600454e-01],
#         [1.95266542e+00],
#         [2.31534882e+00],
#         [1.29373737e+00],
#         [2.34931384e+00],
#         [2.28235706e+00],
#         [2.25445559e+00],
#         [2.21550304e+00],
#         [2.26841435e+00],
#         [1.20388661e-01],
#         [2.83614694e-02],
#         [1.98076790e-01],
#         [1.71747038e-01],
#         [2.66610840e+00],
#         [2.99975179e+00],
#         [8.16099073e-01],
#         [1.56744396e+00],
#         [7.37618615e-01],
#         [8.85260225e-01],
#         [1.50515403e+00],
#         [1.64892988e+00],
#         [2.36089581e-01],
#         [2.56975650e-01],
#         [1.05782205e-04],
# ...
