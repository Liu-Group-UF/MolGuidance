# %%
import pickle

# %%
path = "pkl-files/ag_results_mu_step40000.pkl"
pcikle_file = open(path, 'rb')
data = pickle.load(pcikle_file)

# %%
data
# Out:
# {'best_w1': 2.7144770407655234,
#  'best_w2': 1.1161061180168932,
#  'best_mae': 0.5590446750430856,
#  'guide_ws': array([[3.62859186, 1.14674783],
#         [3.5729803 , 1.47748013],
#         [2.47124808, 1.07997993],
#         [2.51552134, 1.26696689],
#         [1.4714605 , 1.52071078],
#         [1.18615821, 1.57759902],
#         [4.09722394, 1.00062301],
#         [4.27429815, 1.49398521],
#         [3.01845543, 1.00565304],
#         [1.076106  , 1.41981973],
#         [1.        , 1.034037  ],
#         [4.3       , 1.37292282],
#         [4.3       , 1.8       ],
#         [1.        , 1.20221847],
#         [4.3       , 1.0486025 ],
#         [4.3       , 1.59001718],
#         [2.11164972, 1.        ],
#         [2.72131617, 1.37229271],
#         [4.3       , 1.        ],
#         [1.        , 1.8       ],
#         [3.3890522 , 1.3089992 ],
#         [3.41236721, 1.05436601],
#         [2.78476141, 1.58894942],
#         [3.30716424, 1.        ],
# ...
