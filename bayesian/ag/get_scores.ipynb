# %%
from molguidance.utils.sdf_utils import check_valency_charge_balance, get_uniqueness_rate, get_rdkit_valid, get_pb_valid_results

# %%
# Check stability of generated molecules
_, mol_stability, _, _ = check_valency_charge_balance("ag_guidance_best_w.sdf")
print("stability:", mol_stability)
# Out:
# stability: 0.9754

# %%
# Check uniqueness of generated molecules
_, uniqueness_rate = get_uniqueness_rate("ag_guidance_best_w.sdf", n_raw=10000)
print("uniqueness:", uniqueness_rate)
# Out:
# uniqueness: 0.9395

# %%
# Check rdkit valid results
rdkit_valid = get_rdkit_valid("ag_guidance_best_w.sdf", n_mols=10000)
print("rdkit_valid:", rdkit_valid)
# Out:
# rdkit_valid: 0.9932
